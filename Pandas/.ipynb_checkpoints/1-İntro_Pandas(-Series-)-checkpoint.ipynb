# %%
import numpy as np

# %%
import pandas as pd

# %%
grades = {"Gulcohre":50,"Samir":60,"James":30}

# %%
pd.Series(grades)#Datalari birlesdirir
# Out:
# Gulcohre    50
# Samir       60
# James       30
# dtype: int64

# %%
names = ["Gulcohre","Samir","James"]

# %%
grades = [50,60,30]

# %%
pd.Series(grades,names)
# Out:
# Gulcohre    50
# Samir       60
# James       30
# dtype: int64

# %%
pd.Series(data = grades ,index = names)
# Out:
# Gulcohre    50
# Samir       60
# James       30
# dtype: int64

# %%
numpy_array = np.array([50,40,30,20])

# %%
pd.Series(numpy_array)
# Out:
# 0    50
# 1    40
# 2    30
# 3    20
# dtype: int64

# %%
#aritmethic

# %%
contest_result = pd.Series(data = [10,5,100],index = ["Gulcohre","Samir","James"])

# %%
contest_result2 = pd.Series(data = [20,50,10],index = ["Gulcohre","Samir","James"])

# %%
contest_result
# Out:
# Gulcohre     10
# Samir         5
# James       100
# dtype: int64

# %%
contest_result["Samir"]
# Out:
# np.int64(5)

# %%
contest_result2["James"]
# Out:
# np.int64(10)

# %%
final_result = contest_result + contest_result2

# %%
final_result
# Out:
# Gulcohre     30
# Samir        55
# James       110
# dtype: int64

# %%
 contest_result - contest_result2
# Out:
# Gulcohre   -10
# Samir      -45
# James       90
# dtype: int64

# %%
 contest_result * contest_result2
# Out:
# Gulcohre     200
# Samir        250
# James       1000
# dtype: int64

# %%
 contest_result / contest_result2
# Out:
# Gulcohre     0.5
# Samir        0.1
# James       10.0
# dtype: float64

# %%
diffrent_series = pd.Series(data = [20,30,40,50],index = ["a","b","c","d"])

# %%
diffrent_series
# Out:
# a    20
# b    30
# c    40
# d    50
# dtype: int64

# %%
diffrent_series2 = pd.Series(data = [10,5,3,1],index = ["a","c","f","g"])

# %%
diffrent_series2
# Out:
# a    10
# c     5
# f     3
# g     1
# dtype: int64

# %%
diffrent_series + diffrent_series2 #Göründüyü kimi indexlər 
#fərqli olduqu üçün fərqli olanlar NaN qaytardı yəni qısaca hər ikisində olan indeksləri topladı birində olub ddigərində olmayanlarada Nan yazdı
# Out:
# a    30.0
# b     NaN
# c    45.0
# d     NaN
# f     NaN
# g     NaN
# dtype: float64
